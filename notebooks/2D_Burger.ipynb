# %% [markdown]
# ## Imports

# %%
import numpy as np
from matplotlib import pyplot, cm
from mpl_toolkits.mplot3d import Axes3D

import time
from numba import njit
from pyccel.epyccel import epyccel
from pyccel.decorators import types

# %% [markdown]
# ## Pure python function

# %%
def solve_2d_burger_pure(u, un, v, vn, nt, dt, dx, dy, nu):
    
    
    ###Assign initial conditions
    ##set hat function I.C. : u(.5<=x<=1 && .5<=y<=1 ) is 2
    u[int(.5 / dy):int(1 / dy + 1),int(.5 / dx):int(1 / dx + 1)] = 2 
    ##set hat function I.C. : u(.5<=x<=1 && .5<=y<=1 ) is 2
    v[int(.5 / dy):int(1 / dy + 1),int(.5 / dx):int(1 / dx + 1)] = 2
    row, col = u.shape
    
    #fill the update of u and v
    u[0,:]=1
    u[col-1,:]=1
    u[:,0]=1
    u[:,row-1]=1
    v[0,:]=1
    v[col-1,:]=1
    v[:,0]=1
    v[:,row-1]=1
    for n in range(nt):
        for i in range(1,row-1):
            for j in range(1,col-1):
                u[i,j]=u[i,j]-(dt/dx)*u[i,j]*(u[i,j]-u[i-1,j])-v[i,j]*(dt/dy)*(u[i,j]-u[i,j-1])+nu*(dt/dx**2)*(u[i+1,j]-2*u[i,j]+u[i-1,j])+nu*(dt/dy**2)*(u[i,j+1]-2*u[i,j]+u[i,j-1])
                v[i,j]=v[i,j]-(dt/dx)*u[i,j]*(v[i,j]-v[i-1,j])-v[i,j]*(dt/dy)*(v[i,j]-v[i,j-1])+nu*(dt/dx**2)*(v[i+1,j]-2*v[i,j]+v[i-1,j])+nu*(dt/dy**2)*(v[i,j+1]-2*v[i,j]+v[i,j-1])
        
        
    return 0

# %% [markdown]
# ## Numba accelerator

# %%
def solve_2d_burger_numba(u, un, v, vn, nt, dt, dx, dy, nu):
    
    
    ###Assign initial conditions
    ##set hat function I.C. : u(.5<=x<=1 && .5<=y<=1 ) is 2
    u[int(.5 / dy):int(1 / dy + 1),int(.5 / dx):int(1 / dx + 1)] = 2 
    ##set hat function I.C. : u(.5<=x<=1 && .5<=y<=1 ) is 2
    v[int(.5 / dy):int(1 / dy + 1),int(.5 / dx):int(1 / dx + 1)] = 2
    row, col = u.shape
    
    #fill the update of u and v
    u[0,:]=1
    u[col-1,:]=1
    u[:,0]=1
    u[:,row-1]=1
    v[0,:]=1
    v[col-1,:]=1
    v[:,0]=1
    v[:,row-1]=1
    for n in range(nt):
        for i in range(1,row-1):
            for j in range(1,col-1):
                u[i,j]=u[i,j]-(dt/dx)*u[i,j]*(u[i,j]-u[i-1,j])-v[i,j]*(dt/dy)*(u[i,j]-u[i,j-1])+nu*(dt/dx**2)*(u[i+1,j]-2*u[i,j]+u[i-1,j])+nu*(dt/dy**2)*(u[i,j+1]-2*u[i,j]+u[i,j-1])
                v[i,j]=v[i,j]-(dt/dx)*u[i,j]*(v[i,j]-v[i-1,j])-v[i,j]*(dt/dy)*(v[i,j]-v[i,j-1])+nu*(dt/dx**2)*(v[i+1,j]-2*v[i,j]+v[i-1,j])+nu*(dt/dy**2)*(v[i,j+1]-2*v[i,j]+v[i,j-1])
        
    return 0

# %% [markdown]
# ## Pyccel accelerator

# %%
@types('float[:,:]', 'float[:,:]','float[:,:]','float[:,:]','int','float','float','float', 'float')
def solve_2d_burger_pyccel(u, un, v, vn, nt, dt, dx, dy, nu):
    
    
    ###Assign initial conditions
    ##set hat function I.C. : u(.5<=x<=1 && .5<=y<=1 ) is 2
    u[int(.5 / dy):int(1 / dy + 1),int(.5 / dx):int(1 / dx + 1)] = 2 
    ##set hat function I.C. : u(.5<=x<=1 && .5<=y<=1 ) is 2
    v[int(.5 / dy):int(1 / dy + 1),int(.5 / dx):int(1 / dx + 1)] = 2
    row, col = u.shape
    
    #fill the update of u and v
    u[0,:]=1
    u[col-1,:]=1
    u[:,0]=1
    u[:,row-1]=1
    v[0,:]=1
    v[col-1,:]=1
    v[:,0]=1
    v[:,row-1]=1
    for n in range(nt):
        for i in range(1,row-1):
            for j in range(1,col-1):
                u[i,j]=u[i,j]-(dt/dx)*u[i,j]*(u[i,j]-u[i-1,j])-v[i,j]*(dt/dy)*(u[i,j]-u[i,j-1])+nu*(dt/dx**2)*(u[i+1,j]-2*u[i,j]+u[i-1,j])+nu*(dt/dy**2)*(u[i,j+1]-2*u[i,j]+u[i,j-1])
                v[i,j]=v[i,j]-(dt/dx)*u[i,j]*(v[i,j]-v[i-1,j])-v[i,j]*(dt/dy)*(v[i,j]-v[i,j-1])+nu*(dt/dx**2)*(v[i+1,j]-2*v[i,j]+v[i-1,j])+nu*(dt/dy**2)*(v[i,j+1]-2*v[i,j]+v[i,j-1])
        
        
    return 0

# %% [markdown]
# ## Inputs

# %%
###variable declarations
nx = 100
ny = 100
nt = 20
dx = 2 / (nx - 1)
dy = 2 / (ny - 1)
sigma = .0009
nu = 0.01
dt = sigma * dx * dy / nu


x = np.linspace(0, 2, nx)
y = np.linspace(0, 2, ny)

u = np.ones((ny, nx))  # create a 1xn vector of 1's
v = np.ones((ny, nx))
un = np.ones((ny, nx)) 
vn = np.ones((ny, nx))

solve_2d_burger_pure(u, un, v, vn, nt, dt, dx, dy, nu)

X, Y = np.meshgrid(x, y)
fig = pyplot.figure(figsize=(7, 5), dpi=100)
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X, Y, u, rstride=1, cstride=1, cmap=cm.viridis, linewidth=0, antialiased=True)
ax.set_zlim(1, 2.5)
ax.set_xlabel('$x$')
ax.set_ylabel('$y$');

# %% [markdown]
# ## Call Funtions

# %% [markdown]
# ### Pure function

# %%
# %timeit solve_2d_burger_pure(u, un, v, vn, nt, dt, dx, dy, nu)
# Out:
# 1.91 s ± 59.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### Function with numba accelerator

# %%
# %timeit solve_2d_burger_numba(u, un, v, vn, nt, dt, dx, dy, nu)
# Out:
# 1.87 s ± 18.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### Function with pyccel accelerator

# %%
solve_2d_burger_f90 = epyccel(solve_2d_burger_pyccel)

# %%
# %timeit solve_2d_burger_f90(u, un, v, vn, nt, dt, dx, dy, nu)
# Out:
# 1.32 ms ± 3.63 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
