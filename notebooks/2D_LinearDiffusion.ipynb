# %% [markdown]
# ## Imports

# %%
import numpy as np
from matplotlib import pyplot, cm
from mpl_toolkits.mplot3d import Axes3D


import time
from numba import njit
from pyccel.epyccel import epyccel
from pyccel.decorators import types

# %% [markdown]
# ## Pure python function

# %%
def solve_2d_diff_pure(u,nt, dt, dx, dy, nu):
    row, col = u.shape
    
    ###Assign initial conditions
    # set hat function I.C. : u(.5<=x<=1 && .5<=y<=1 ) is 2
    u[int(.5 / dy):int(1 / dy + 1),int(.5 / dx):int(1 / dx + 1)] = 2
 #fill the update of u and v
    u[0,:]=1
    u[col-1,:]=1
    u[:,0]=1
    u[:,row-1]=1
    
    for n in range(nt):
        for i in range(1,row-1):
            for j in range(1,col-1):
                u[i,j]=u[i,j]+nu*(dt/dx**2)*(u[i+1,j]-2*u[i,j]+u[i-1,j])+nu*(dt/dy**2)*(u[i,j+1]-2*u[i,j]+u[i,j-1])   
    return 0

# %% [markdown]
# ## Numba accelerator

# %%
@njit(fastmath=True)
def solve_2d_diff_numba(u, nt,dt, dx, dy, nu):
    row, col = u.shape
    
    ###Assign initial conditions
    # set hat function I.C. : u(.5<=x<=1 && .5<=y<=1 ) is 2
    u[int(.5 / dy):int(1 / dy + 1),int(.5 / dx):int(1 / dx + 1)] = 2
    
    
    #fill the update of u
    u[0,:]=1
    u[ny-1,:]=1
    u[:,0]=1
    u[:,nx-1]=1
    
    for n in range(nt):
        for i in range(1,nx-1):
            for j in range(1,ny-1):
                u[i,j]=u[i,j]+nu*(dt/dx**2)*(u[i+1,j]-2*u[i,j]+u[i-1,j])+nu*(dt/dy**2)*(u[i,j+1]-2*u[i,j]+u[i,j-1])  
    return 0

# %% [markdown]
# ## Pyccel accelerator

# %%
@types('float[:,:]','int','float','float','float','float')
def solve_2d_diff_pyccel(u, nt,dt, dx, dy, nu):
    row, col = u.shape
    
    ##Assign initial conditions
    #set hat function I.C. : u(.5<=x<=1 && .5<=y<=1 ) is 2
    u[int(.5 / dy):int(1 / dy + 1),int(.5 / dx):int(1 / dx + 1)] = 2
    
    
    #fill the update of u and v
    u[0,:]=1
    u[col-1,:]=1
    u[:,0]=1
    u[:,row-1]=1
    
    for n in range(nt):
        for i in range(1,row-1):
            for j in range(1,col-1):
                u[i,j]=u[i,j]+nu*(dt/dx**2)*(u[i+1,j]-2*u[i,j]+u[i-1,j])+nu*(dt/dy**2)*(u[i,j+1]-2*u[i,j]+u[i,j-1])   
    return 0

# %% [markdown]
# ## Inputs

# %%
###variable declarations
nt =20
nx = 150
ny = 150
nu = .004
dx = 2 / (nx - 1)
dy = 2 / (ny - 1)
sigma = .25
dt = sigma * dx * dy / nu

x = np.linspace(0, 2, nx)
y = np.linspace(0, 2, ny)

u = np.ones((ny, nx))  # create a 1xn vector of 1's
un = np.ones((ny, nx))
    

solve_2d_diff_pure(u, nt,dt, dx, dy, nu)

fig = pyplot.figure(figsize=(7, 5), dpi=100)
ax = fig.gca(projection='3d')                      
X, Y = np.meshgrid(x, y)                            
surf = ax.plot_surface(X, Y, u, cmap=cm.viridis)

# %% [markdown]
# ## Call Funtions

# %% [markdown]
# ### Pure function

# %%
# %timeit solve_2d_diff_pure(u, nt,dt, dx, dy, nu)
# Out:
# 1.29 s ± 25 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### Function with numba accelerator

# %%
# %timeit solve_2d_diff_numba(u, nt,dt, dx, dy, nu)
# Out:
# 2.31 ms ± 9.97 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### Function with pyccel accelerator

# %%
solve_2d_diff_f90 = epyccel(solve_2d_diff_pyccel)

# %%
# %timeit solve_2d_diff_f90(u,nt, dt, dx, dy, nu)
# Out:
# 1.63 ms ± 14.5 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
